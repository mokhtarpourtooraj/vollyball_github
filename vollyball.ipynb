# %% [markdown]
# <a href="https://colab.research.google.com/github/mokhtarpourtooraj/vollyball_github/blob/master/vollyball.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR='/content/MyDrive/vollyball'

# %%
# %cd {ROOT_DIR}
# Out:
# [Errno 2] No such file or directory: '/content/MyDrive/vollyball'
# /content

# %%
# !git clone https://github.com//ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 7664, done.
# remote: Counting objects: 100% (1268/1268), done.
# remote: Compressing objects: 100% (616/616), done.
# remote: Total 7664 (delta 773), reused 1052 (delta 642), pack-reused 6396
# Receiving objects: 100% (7664/7664), 5.67 MiB | 26.03 MiB/s, done.
# Resolving deltas: 100% (5117/5117), done.

# %%
# %ls
# Out:
# gdrive/  sample_data/  ultralytics/

# %%
# %cd ultralytics
# Out:
# /content/ultralytics

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.4/530.4 kB 23.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.5/199.5 kB 25.5 MB/s eta 0:00:00
# ...

# %%
# !pip install ipython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 47.6 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from IPython.display import Image as imgshow
import os

# %%
# !pip install roboflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="MEkmXYYIEoB57SmAecwS")
project = rf.workspace("herbarium-data").project("vollyball")
dataset = project.version(4).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.88, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to vollyball-4 in yolov8:: 100%|██████████| 1106/1106 [00:00<00:00, 1425.14it/s]

# %%
{dataset.location}
# Out:
# {'/content/vollyball-4'}

# %%
{'/content/vollyball-4'}
# Out:
# {'/content/vollyball-4'}

# %%
# !yolo  task=detect  mode=train  model=yolov8m.pt  data={dataset.location}/data.yaml epochs=40 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 55.2MB/s]
# Ultralytics YOLOv8.0.88 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo  task=detect  mode=train  model=yolov8m.pt  data={dataset.location}/data.yaml epochs=60 imgsz=640
# Out:
# Ultralytics YOLOv8.0.88 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo  task=detect  mode=train  model=yolov8m.pt  data={dataset.location}/data.yaml epochs=80 imgsz=640
# Out:
# Ultralytics YOLOv8.0.88 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo  task=detect  mode=val  model=/content/runs/detect/train3/weights/best.pt  data=/content/vollyball-4/data.yaml
# Out:
# Ultralytics YOLOv8.0.88 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/vollyball-4/valid/labels.cache... 98 images, 0 backgrounds, 0 corrupt: 100% 98/98 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 173, len(boxes) = 177. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:06<00:00,  1.06it/s]
#                    all         98        177      0.901      0.896      0.914      0.682
#                   ball         98         75      0.954       0.88      0.928      0.564
#                    net         98        102      0.848      0.912      0.899        0.8
# ...

# %%
# !yolo  task=detect  mode=predict  model=/content/runs/detect/train3/weights/best.pt conf=0.70 source=/content/vollyball-4/test/images
# Out:
# Ultralytics YOLOv8.0.88 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/39 /content/vollyball-4/test/images/114_jpg.rf.a1b7795ac17870df09cb11ab68921d1b.jpg: 640x640 1 ball, 1 net, 37.6ms
# image 2/39 /content/vollyball-4/test/images/116_jpg.rf.7fad0eecb6ebeb57634579bf1ab8100a.jpg: 640x640 1 net, 37.0ms
# image 3/39 /content/vollyball-4/test/images/126_JPG.rf.1be8f5bc780acb8954c4f88c5775a54e.jpg: 640x640 1 ball, 2 nets, 36.9ms
# image 4/39 /content/vollyball-4/test/images/135_jpg.rf.7f536c1c8439cb83a6086964d6c98eeb.jpg: 640x640 1 net, 32.2ms
# image 5/39 /content/vollyball-4/test/images/143_jpg.rf.87938ebba242cb7541ebdcc6f1c000a6.jpg: 640x640 1 net, 29.9ms
# image 6/39 /content/vollyball-4/test/images/153_jpg.rf.256b95119c5da5723d556cf399a57d03.jpg: 640x640 1 ball, 29.9ms
# ...

# %%
# !yolo export model=/content/runs/detect/train3/weights/best.pt format=onnx
# Out:
# Ultralytics YOLOv8.0.88 🚀 Python-3.10.11 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#
# PyTorch: starting from /content/runs/detect/train3/weights/best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (49.6 MB)
# requirements: YOLOv8 requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 303.5 MB/s eta 0:00:00
# ...
#
# requirements: 1 package updated per ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.13.1 opset 17...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ...

# %%
# !yolo  task=detect  mode=predict  model=/content/runs/detect/train3/weights/best.pt  source=/content/vollyball-4/test/images

# %% [markdown]
# # New Section
